# %%
from rdkit import Chem
from rdkit.Chem import Draw
import re

# %%
base_rings = ['c1ccccc1', #benzene
               'n1ccccc1', #pyridine
               'o1cccc1',  #furan
               's1cccc1',  #thiophene
               '[nH]1cccc1', #pyrrole
               'n1c[nH]cc1', #imidazole
               'c1ccc2ccccc2c1', #naphthalene
               'c1ccc2cc3ccccc3cc2c1'] #anthracene

free_carbon_search_patterns = ['c1c', r'1c\[n', 'cc', r'c\[nH\]']
free_carbon_insert_points = [2, 2, 1, 1]

clean_ring_locations = [
  [1], #benzene
  [2, 3, 4], #pyridine
  [2, 3], #furan
  [2, 3], #thiophene
  [5, 6], #pyrrole
  [2, 7, 9], #imidazole
  [1, 3], #naphthalene
  [1, 3, 6]  #anthracene
]

e_withdraw = ['I', 'Br', 'Cl', 'F', 'C(Cl)(Cl)(Cl)', 'C(F)(F)(F)', 'C(=O)[O-]', 'C(=O)', 'C#N', '[N+](=O)[O-]', '[NH3+]']

e_donate = electron_donating_groups = [
    "[O-]",          # Phenoxide (strongest resonance donor)
    "N(C)C",         # Dimethylamino (-NMe2)
    "NC",            # Methylamino (-NHMe)
    "N",             # Amino (-NH2)
    "O",             # Hydroxy (-OH)
    "OC",            # Methoxy (-OMe)
    "NC(=O)C",       # Acetamido (-NHCOCH3)
    "SC",            # Methylthio (-SMe)
    "OC(=O)C",       # Acetoxy (-OCOCH3)
    "C(C)(C)C",      # tert-Butyl (-C(CH3)3)
    "C(C)C",         # Isopropyl (-CHMe2)
    "CC",            # Ethyl (-Et)
    "C",             # Methyl (-Me)
    "c1ccccc1",      # Phenyl (-Ph)
    "C=C",           # Vinyl (-CH=CH2)
    "[Si](C)(C)C"    # Trimethylsilyl (-SiMe3)
]

target = 'hey'

# %%
def sub_cycle(best_smiles = '', best_score = 0, substituents = e_withdraw, target = target):
  '''

  '''
  for ring, locs in zip(base_rings, clean_ring_locations):
    for loc in locs:

      for e in substituents:

        new_smiles = f'{ring[:loc+1]}({e}){ring[loc+1:]}'
        new_mol = Chem.MolFromSmiles(new_smiles)
        if new_mol != None:
          print(new_smiles)
          try:
              score, aux = 1, 2 #target.dock(new_smiles, 32)
          except:
              print(f"Error docking {new_smiles}")
              score = 0.0
          #print(f"{new_smiles}: {score}")
          if score < best_score:
            best_score = score
            best_smiles = new_smiles       
            print(f"=========== New best score: {best_score} for {new_smiles} ======")
        else:
          print(new_smiles, 'bad')

  print(f"Best score: {best_score} for {best_smiles}")

  return best_smiles, best_score

def grow_cycle(best_smiles = '', best_score = 0, substituents = e_withdraw, target = target):
    '''
    add substituents to free carbons in the molecule. 
    '''
    match_indices = []
    for pattern, insert_point in zip(free_carbon_search_patterns, free_carbon_insert_points):
        for match in re.finditer(f'(?={pattern})', best_smiles):
            match_indices.append((pattern, best_smiles, match.start()))
            print(f'found match for {pattern} at {match.start() + insert_point}, {match.start()}')
            for e in e_withdraw:
                new_smiles = f'{best_smiles[:match.start() + insert_point]}({e}){best_smiles[match.start() + insert_point:]}'
                mol = Chem.MolFromSmiles(new_smiles)
                if mol != None:
                    print(new_smiles)
                    try:
                        score, aux = 1, 2 #target.dock(new_smiles, 32)
                    except:
                        print(f"Error docking {new_smiles}")
                        score = 0.0
                    #print(f"{new_smiles}: {score}")
                    if score < best_score:
                        best_score = score
                        best_smiles = new_smiles       
                        print(f"=========== New best score: {best_score} for {new_smiles} ========")
                else:
                    print(new_smiles, 'bad')
    print(f"Best score: {best_score} for {best_smiles}")
    return best_smiles, best_score

# %%
bs, bs2 = grow_cycle(base_rings[6])
# Out:
# found match for c1c at 2, 0
# c1(I)ccc2ccccc2c1
# c1(Br)ccc2ccccc2c1
# c1(Cl)ccc2ccccc2c1
# c1(F)ccc2ccccc2c1
# c1(C(Cl)(Cl)(Cl))ccc2ccccc2c1
# c1(C(F)(F)(F))ccc2ccccc2c1
# c1(C(=O)[O-])ccc2ccccc2c1
# c1(C(=O))ccc2ccccc2c1
# c1(C#N)ccc2ccccc2c1
# c1([N+](=O)[O-])ccc2ccccc2c1
# c1([NH3+])ccc2ccccc2c1
# found match for cc at 3, 2
# c1c(I)cc2ccccc2c1
# c1c(Br)cc2ccccc2c1
# c1c(Cl)cc2ccccc2c1
# c1c(F)cc2ccccc2c1
# c1c(C(Cl)(Cl)(Cl))cc2ccccc2c1
# c1c(C(F)(F)(F))cc2ccccc2c1
# c1c(C(=O)[O-])cc2ccccc2c1
# c1c(C(=O))cc2ccccc2c1
# c1c(C#N)cc2ccccc2c1
# c1c([N+](=O)[O-])cc2ccccc2c1
# c1c([NH3+])cc2ccccc2c1
# found match for cc at 4, 3
# c1cc(I)c2ccccc2c1
# c1cc(Br)c2ccccc2c1
# c1cc(Cl)c2ccccc2c1
# c1cc(F)c2ccccc2c1
# c1cc(C(Cl)(Cl)(Cl))c2ccccc2c1
# c1cc(C(F)(F)(F))c2ccccc2c1
# c1cc(C(=O)[O-])c2ccccc2c1
# c1cc(C(=O))c2ccccc2c1
# c1cc(C#N)c2ccccc2c1
# c1cc([N+](=O)[O-])c2ccccc2c1
# c1cc([NH3+])c2ccccc2c1
# found match for cc at 7, 6
# c1ccc2c(I)cccc2c1
# c1ccc2c(Br)cccc2c1
# c1ccc2c(Cl)cccc2c1
# c1ccc2c(F)cccc2c1
# c1ccc2c(C(Cl)(Cl)(Cl))cccc2c1
# c1ccc2c(C(F)(F)(F))cccc2c1
# c1ccc2c(C(=O)[O-])cccc2c1
# c1ccc2c(C(=O))cccc2c1
# c1ccc2c(C#N)cccc2c1
# c1ccc2c([N+](=O)[O-])cccc2c1
# c1ccc2c([NH3+])cccc2c1
# found match for cc at 8, 7
# c1ccc2cc(I)ccc2c1
# c1ccc2cc(Br)ccc2c1
# c1ccc2cc(Cl)ccc2c1
# c1ccc2cc(F)ccc2c1
# c1ccc2cc(C(Cl)(Cl)(Cl))ccc2c1
# c1ccc2cc(C(F)(F)(F))ccc2c1
# c1ccc2cc(C(=O)[O-])ccc2c1
# c1ccc2cc(C(=O))ccc2c1
# c1ccc2cc(C#N)ccc2c1
# c1ccc2cc([N+](=O)[O-])ccc2c1
# c1ccc2cc([NH3+])ccc2c1
# found match for cc at 9, 8
# c1ccc2ccc(I)cc2c1
# c1ccc2ccc(Br)cc2c1
# c1ccc2ccc(Cl)cc2c1
# c1ccc2ccc(F)cc2c1
# c1ccc2ccc(C(Cl)(Cl)(Cl))cc2c1
# c1ccc2ccc(C(F)(F)(F))cc2c1
# c1ccc2ccc(C(=O)[O-])cc2c1
# c1ccc2ccc(C(=O))cc2c1
# c1ccc2ccc(C#N)cc2c1
# c1ccc2ccc([N+](=O)[O-])cc2c1
# c1ccc2ccc([NH3+])cc2c1
# found match for cc at 10, 9
# c1ccc2cccc(I)c2c1
# c1ccc2cccc(Br)c2c1
# c1ccc2cccc(Cl)c2c1
# c1ccc2cccc(F)c2c1
# c1ccc2cccc(C(Cl)(Cl)(Cl))c2c1
# c1ccc2cccc(C(F)(F)(F))c2c1
# c1ccc2cccc(C(=O)[O-])c2c1
# c1ccc2cccc(C(=O))c2c1
# c1ccc2cccc(C#N)c2c1
# c1ccc2cccc([N+](=O)[O-])c2c1
# c1ccc2cccc([NH3+])c2c1
# found match for c2c at 6, 4
# c1ccc2(I)ccccc2c1 bad
# c1ccc2(Br)ccccc2c1 bad
# c1ccc2(Cl)ccccc2c1 bad
# c1ccc2(F)ccccc2c1 bad
# c1ccc2(C(Cl)(Cl)(Cl))ccccc2c1 bad
# c1ccc2(C(F)(F)(F))ccccc2c1 bad
# c1ccc2(C(=O)[O-])ccccc2c1 bad
# c1ccc2(C(=O))ccccc2c1 bad
# c1ccc2(C#N)ccccc2c1 bad
# c1ccc2([N+](=O)[O-])ccccc2c1 bad
# c1ccc2([NH3+])ccccc2c1 bad
# found match for c2c at 12, 10
# c1ccc2ccccc2(I)c1 bad
# c1ccc2ccccc2(Br)c1 bad
# c1ccc2ccccc2(Cl)c1 bad
# c1ccc2ccccc2(F)c1 bad
# c1ccc2ccccc2(C(Cl)(Cl)(Cl))c1 bad
# c1ccc2ccccc2(C(F)(F)(F))c1 bad
# c1ccc2ccccc2(C(=O)[O-])c1 bad
# c1ccc2ccccc2(C(=O))c1 bad
# c1ccc2ccccc2(C#N)c1 bad
# c1ccc2ccccc2([N+](=O)[O-])c1 bad
# c1ccc2ccccc2([NH3+])c1 bad
# Best score: 0 for c1ccc2ccccc2c1
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6 7 8 9 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6 7 8 9 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6 7 8 9 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6 7 8 9 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 8 9 10 11 12 13
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 8 9 10 11 12 13
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 7 8 9 10 11 12
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 6 7 8 9 10 11
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 6 7 8 9 10 11
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 7 8 9 10 11 12
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 5 6 7 8 9 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 10
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 13
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 13
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 12
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 11
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 11
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 12
# [17:09:48] Can't kekulize mol.  Unkekulized atoms: 0 1 2 3 4 5 6 7 10

# %%
mols = [Chem.MolFromSmiles(s) for s in base_rings]
Draw.MolsToGridImage(mols)

# %%
bs, bs2 = sub_cycle()
# Out:
# c1(I)ccccc1
# c1(Br)ccccc1
# c1(Cl)ccccc1
# c1(F)ccccc1
# c1(C(Cl)(Cl)(Cl))ccccc1
# c1(C(F)(F)(F))ccccc1
# c1(C(=O)[O-])ccccc1
# c1(C(=O))ccccc1
# c1(C#N)ccccc1
# c1([N+](=O)[O-])ccccc1
# c1([NH3+])ccccc1
# n1c(I)cccc1
# n1c(Br)cccc1
# n1c(Cl)cccc1
# n1c(F)cccc1
# n1c(C(Cl)(Cl)(Cl))cccc1
# n1c(C(F)(F)(F))cccc1
# n1c(C(=O)[O-])cccc1
# n1c(C(=O))cccc1
# n1c(C#N)cccc1
# n1c([N+](=O)[O-])cccc1
# n1c([NH3+])cccc1
# n1cc(I)ccc1
# n1cc(Br)ccc1
# n1cc(Cl)ccc1
# n1cc(F)ccc1
# n1cc(C(Cl)(Cl)(Cl))ccc1
# n1cc(C(F)(F)(F))ccc1
# n1cc(C(=O)[O-])ccc1
# n1cc(C(=O))ccc1
# n1cc(C#N)ccc1
# n1cc([N+](=O)[O-])ccc1
# n1cc([NH3+])ccc1
# n1ccc(I)cc1
# n1ccc(Br)cc1
# n1ccc(Cl)cc1
# n1ccc(F)cc1
# n1ccc(C(Cl)(Cl)(Cl))cc1
# n1ccc(C(F)(F)(F))cc1
# n1ccc(C(=O)[O-])cc1
# n1ccc(C(=O))cc1
# n1ccc(C#N)cc1
# n1ccc([N+](=O)[O-])cc1
# n1ccc([NH3+])cc1
# o1c(I)ccc1
# o1c(Br)ccc1
# o1c(Cl)ccc1
# o1c(F)ccc1
# o1c(C(Cl)(Cl)(Cl))ccc1
# o1c(C(F)(F)(F))ccc1
# o1c(C(=O)[O-])ccc1
# o1c(C(=O))ccc1
# o1c(C#N)ccc1
# o1c([N+](=O)[O-])ccc1
# o1c([NH3+])ccc1
# o1cc(I)cc1
# o1cc(Br)cc1
# o1cc(Cl)cc1
# o1cc(F)cc1
# o1cc(C(Cl)(Cl)(Cl))cc1
# o1cc(C(F)(F)(F))cc1
# o1cc(C(=O)[O-])cc1
# o1cc(C(=O))cc1
# o1cc(C#N)cc1
# o1cc([N+](=O)[O-])cc1
# o1cc([NH3+])cc1
# s1c(I)ccc1
# s1c(Br)ccc1
# s1c(Cl)ccc1
# s1c(F)ccc1
# s1c(C(Cl)(Cl)(Cl))ccc1
# s1c(C(F)(F)(F))ccc1
# s1c(C(=O)[O-])ccc1
# s1c(C(=O))ccc1
# s1c(C#N)ccc1
# s1c([N+](=O)[O-])ccc1
# s1c([NH3+])ccc1
# s1cc(I)cc1
# s1cc(Br)cc1
# s1cc(Cl)cc1
# s1cc(F)cc1
# s1cc(C(Cl)(Cl)(Cl))cc1
# s1cc(C(F)(F)(F))cc1
# s1cc(C(=O)[O-])cc1
# s1cc(C(=O))cc1
# s1cc(C#N)cc1
# s1cc([N+](=O)[O-])cc1
# s1cc([NH3+])cc1
# [nH]1c(I)ccc1
# [nH]1c(Br)ccc1
# [nH]1c(Cl)ccc1
# [nH]1c(F)ccc1
# [nH]1c(C(Cl)(Cl)(Cl))ccc1
# [nH]1c(C(F)(F)(F))ccc1
# [nH]1c(C(=O)[O-])ccc1
# [nH]1c(C(=O))ccc1
# [nH]1c(C#N)ccc1
# [nH]1c([N+](=O)[O-])ccc1
# [nH]1c([NH3+])ccc1
# [nH]1cc(I)cc1
# [nH]1cc(Br)cc1
# [nH]1cc(Cl)cc1
# [nH]1cc(F)cc1
# [nH]1cc(C(Cl)(Cl)(Cl))cc1
# [nH]1cc(C(F)(F)(F))cc1
# [nH]1cc(C(=O)[O-])cc1
# [nH]1cc(C(=O))cc1
# [nH]1cc(C#N)cc1
# [nH]1cc([N+](=O)[O-])cc1
# [nH]1cc([NH3+])cc1
# n1c(I)[nH]cc1
# n1c(Br)[nH]cc1
# n1c(Cl)[nH]cc1
# n1c(F)[nH]cc1
# n1c(C(Cl)(Cl)(Cl))[nH]cc1
# n1c(C(F)(F)(F))[nH]cc1
# n1c(C(=O)[O-])[nH]cc1
# n1c(C(=O))[nH]cc1
# n1c(C#N)[nH]cc1
# n1c([N+](=O)[O-])[nH]cc1
# n1c([NH3+])[nH]cc1
# n1c[nH]c(I)c1
# n1c[nH]c(Br)c1
# n1c[nH]c(Cl)c1
# n1c[nH]c(F)c1
# n1c[nH]c(C(Cl)(Cl)(Cl))c1
# n1c[nH]c(C(F)(F)(F))c1
# n1c[nH]c(C(=O)[O-])c1
# n1c[nH]c(C(=O))c1
# n1c[nH]c(C#N)c1
# n1c[nH]c([N+](=O)[O-])c1
# n1c[nH]c([NH3+])c1
# n1c[nH]cc1(I)
# n1c[nH]cc1(Br)
# n1c[nH]cc1(Cl)
# n1c[nH]cc1(F)
# n1c[nH]cc1(C(Cl)(Cl)(Cl))
# n1c[nH]cc1(C(F)(F)(F))
# n1c[nH]cc1(C(=O)[O-])
# n1c[nH]cc1(C(=O))
# n1c[nH]cc1(C#N)
# n1c[nH]cc1([N+](=O)[O-])
# n1c[nH]cc1([NH3+])
# c1(I)ccc2ccccc2c1
# c1(Br)ccc2ccccc2c1
# c1(Cl)ccc2ccccc2c1
# c1(F)ccc2ccccc2c1
# c1(C(Cl)(Cl)(Cl))ccc2ccccc2c1
# c1(C(F)(F)(F))ccc2ccccc2c1
# c1(C(=O)[O-])ccc2ccccc2c1
# c1(C(=O))ccc2ccccc2c1
# c1(C#N)ccc2ccccc2c1
# c1([N+](=O)[O-])ccc2ccccc2c1
# c1([NH3+])ccc2ccccc2c1
# c1cc(I)c2ccccc2c1
# c1cc(Br)c2ccccc2c1
# c1cc(Cl)c2ccccc2c1
# c1cc(F)c2ccccc2c1
# c1cc(C(Cl)(Cl)(Cl))c2ccccc2c1
# c1cc(C(F)(F)(F))c2ccccc2c1
# c1cc(C(=O)[O-])c2ccccc2c1
# c1cc(C(=O))c2ccccc2c1
# c1cc(C#N)c2ccccc2c1
# c1cc([N+](=O)[O-])c2ccccc2c1
# c1cc([NH3+])c2ccccc2c1
# c1(I)ccc2cc3ccccc3cc2c1
# c1(Br)ccc2cc3ccccc3cc2c1
# c1(Cl)ccc2cc3ccccc3cc2c1
# c1(F)ccc2cc3ccccc3cc2c1
# c1(C(Cl)(Cl)(Cl))ccc2cc3ccccc3cc2c1
# c1(C(F)(F)(F))ccc2cc3ccccc3cc2c1
# c1(C(=O)[O-])ccc2cc3ccccc3cc2c1
# c1(C(=O))ccc2cc3ccccc3cc2c1
# c1(C#N)ccc2cc3ccccc3cc2c1
# c1([N+](=O)[O-])ccc2cc3ccccc3cc2c1
# c1([NH3+])ccc2cc3ccccc3cc2c1
# c1cc(I)c2cc3ccccc3cc2c1
# c1cc(Br)c2cc3ccccc3cc2c1
# c1cc(Cl)c2cc3ccccc3cc2c1
# c1cc(F)c2cc3ccccc3cc2c1
# c1cc(C(Cl)(Cl)(Cl))c2cc3ccccc3cc2c1
# c1cc(C(F)(F)(F))c2cc3ccccc3cc2c1
# c1cc(C(=O)[O-])c2cc3ccccc3cc2c1
# c1cc(C(=O))c2cc3ccccc3cc2c1
# c1cc(C#N)c2cc3ccccc3cc2c1
# c1cc([N+](=O)[O-])c2cc3ccccc3cc2c1
# c1cc([NH3+])c2cc3ccccc3cc2c1
# c1ccc2c(I)c3ccccc3cc2c1
# c1ccc2c(Br)c3ccccc3cc2c1
# c1ccc2c(Cl)c3ccccc3cc2c1
# c1ccc2c(F)c3ccccc3cc2c1
# c1ccc2c(C(Cl)(Cl)(Cl))c3ccccc3cc2c1
# c1ccc2c(C(F)(F)(F))c3ccccc3cc2c1
# c1ccc2c(C(=O)[O-])c3ccccc3cc2c1
# c1ccc2c(C(=O))c3ccccc3cc2c1
# c1ccc2c(C#N)c3ccccc3cc2c1
# c1ccc2c([N+](=O)[O-])c3ccccc3cc2c1
# c1ccc2c([NH3+])c3ccccc3cc2c1
# Best score: 0 for

# %%
for i in range(len(base_rings)):
    bs, bs2 = grow_cycle(base_rings[i])
# Out:
# found match
# c1(I)ccccc1
# c1(Br)ccccc1
# c1(Cl)ccccc1
# c1(F)ccccc1
# c1(C(Cl)(Cl)(Cl))ccccc1
# c1(C(F)(F)(F))ccccc1
# c1(C(=O)[O-])ccccc1
# c1(C(=O))ccccc1
# c1(C#N)ccccc1
# c1([N+](=O)[O-])ccccc1
# c1([NH3+])ccccc1
# found match
# c1c(I)cccc1
# c1c(Br)cccc1
# c1c(Cl)cccc1
# c1c(F)cccc1
# c1c(C(Cl)(Cl)(Cl))cccc1
# c1c(C(F)(F)(F))cccc1
# c1c(C(=O)[O-])cccc1
# c1c(C(=O))cccc1
# c1c(C#N)cccc1
# c1c([N+](=O)[O-])cccc1
# c1c([NH3+])cccc1
# found match
# c1ccc(I)cc1
# c1ccc(Br)cc1
# c1ccc(Cl)cc1
# c1ccc(F)cc1
# c1ccc(C(Cl)(Cl)(Cl))cc1
# c1ccc(C(F)(F)(F))cc1
# c1ccc(C(=O)[O-])cc1
# c1ccc(C(=O))cc1
# c1ccc(C#N)cc1
# c1ccc([N+](=O)[O-])cc1
# c1ccc([NH3+])cc1
# Best score: 0 for c1ccccc1
# found match
# n1ccc(I)cc1
# n1ccc(Br)cc1
# n1ccc(Cl)cc1
# n1ccc(F)cc1
# n1ccc(C(Cl)(Cl)(Cl))cc1
# n1ccc(C(F)(F)(F))cc1
# n1ccc(C(=O)[O-])cc1
# n1ccc(C(=O))cc1
# n1ccc(C#N)cc1
# n1ccc([N+](=O)[O-])cc1
# n1ccc([NH3+])cc1
# found match
# n1c(I)cccc1
# n1c(Br)cccc1
# n1c(Cl)cccc1
# n1c(F)cccc1
# n1c(C(Cl)(Cl)(Cl))cccc1
# n1c(C(F)(F)(F))cccc1
# n1c(C(=O)[O-])cccc1
# n1c(C(=O))cccc1
# n1c(C#N)cccc1
# n1c([N+](=O)[O-])cccc1
# n1c([NH3+])cccc1
# found match
# n1ccc(I)cc1
# n1ccc(Br)cc1
# n1ccc(Cl)cc1
# n1ccc(F)cc1
# n1ccc(C(Cl)(Cl)(Cl))cc1
# n1ccc(C(F)(F)(F))cc1
# n1ccc(C(=O)[O-])cc1
# n1ccc(C(=O))cc1
# n1ccc(C#N)cc1
# n1ccc([N+](=O)[O-])cc1
# n1ccc([NH3+])cc1
# Best score: 0 for n1ccccc1
# found match
# o1c(I)ccc1
# o1c(Br)ccc1
# o1c(Cl)ccc1
# o1c(F)ccc1
# o1c(C(Cl)(Cl)(Cl))ccc1
# o1c(C(F)(F)(F))ccc1
# o1c(C(=O)[O-])ccc1
# o1c(C(=O))ccc1
# o1c(C#N)ccc1
# o1c([N+](=O)[O-])ccc1
# o1c([NH3+])ccc1
# found match
# o1ccc(I)c1
# o1ccc(Br)c1
# o1ccc(Cl)c1
# o1ccc(F)c1
# o1ccc(C(Cl)(Cl)(Cl))c1
# o1ccc(C(F)(F)(F))c1
# o1ccc(C(=O)[O-])c1
# o1ccc(C(=O))c1
# o1ccc(C#N)c1
# o1ccc([N+](=O)[O-])c1
# o1ccc([NH3+])c1
# Best score: 0 for o1cccc1
# found match
# s1c(I)ccc1
# s1c(Br)ccc1
# s1c(Cl)ccc1
# s1c(F)ccc1
# s1c(C(Cl)(Cl)(Cl))ccc1
# s1c(C(F)(F)(F))ccc1
# s1c(C(=O)[O-])ccc1
# s1c(C(=O))ccc1
# s1c(C#N)ccc1
# s1c([N+](=O)[O-])ccc1
# s1c([NH3+])ccc1
# found match
# s1ccc(I)c1
# s1ccc(Br)c1
# s1ccc(Cl)c1
# s1ccc(F)c1
# s1ccc(C(Cl)(Cl)(Cl))c1
# s1ccc(C(F)(F)(F))c1
# s1ccc(C(=O)[O-])c1
# s1ccc(C(=O))c1
# s1ccc(C#N)c1
# s1ccc([N+](=O)[O-])c1
# s1ccc([NH3+])c1
# Best score: 0 for s1cccc1
# found match
# [nH]1c(I)ccc1
# [nH]1c(Br)ccc1
# [nH]1c(Cl)ccc1
# [nH]1c(F)ccc1
# [nH]1c(C(Cl)(Cl)(Cl))ccc1
# [nH]1c(C(F)(F)(F))ccc1
# [nH]1c(C(=O)[O-])ccc1
# [nH]1c(C(=O))ccc1
# [nH]1c(C#N)ccc1
# [nH]1c([N+](=O)[O-])ccc1
# [nH]1c([NH3+])ccc1
# found match
# [nH]1ccc(I)c1
# [nH]1ccc(Br)c1
# [nH]1ccc(Cl)c1
# [nH]1ccc(F)c1
# [nH]1ccc(C(Cl)(Cl)(Cl))c1
# [nH]1ccc(C(F)(F)(F))c1
# [nH]1ccc(C(=O)[O-])c1
# [nH]1ccc(C(=O))c1
# [nH]1ccc(C#N)c1
# [nH]1ccc([N+](=O)[O-])c1
# [nH]1ccc([NH3+])c1
# Best score: 0 for [nH]1cccc1
# found match
# n1c[n(I)H]cc1 bad
# n1c[n(Br)H]cc1 bad
# n1c[n(Cl)H]cc1 bad
# n1c[n(F)H]cc1 bad
# n1c[n(C(Cl)(Cl)(Cl))H]cc1 bad
# n1c[n(C(F)(F)(F))H]cc1 bad
# n1c[n(C(=O)[O-])H]cc1 bad
# n1c[n(C(=O))H]cc1 bad
# n1c[n(C#N)H]cc1 bad
# n1c[n([N+](=O)[O-])H]cc1 bad
# n1c[n([NH3+])H]cc1 bad
# found match
# n1c[nH]c(I)c1
# n1c[nH]c(Br)c1
# n1c[nH]c(Cl)c1
# n1c[nH]c(F)c1
# n1c[nH]c(C(Cl)(Cl)(Cl))c1
# n1c[nH]c(C(F)(F)(F))c1
# n1c[nH]c(C(=O)[O-])c1
# n1c[nH]c(C(=O))c1
# n1c[nH]c(C#N)c1
# n1c[nH]c([N+](=O)[O-])c1
# n1c[nH]c([NH3+])c1
# Best score: 0 for n1c[nH]cc1
# found match
# c1(I)ccc2ccccc2c1
# c1(Br)ccc2ccccc2c1
# c1(Cl)ccc2ccccc2c1
# c1(F)ccc2ccccc2c1
# c1(C(Cl)(Cl)(Cl))ccc2ccccc2c1
# c1(C(F)(F)(F))ccc2ccccc2c1
# c1(C(=O)[O-])ccc2ccccc2c1
# c1(C(=O))ccc2ccccc2c1
# c1(C#N)ccc2ccccc2c1
# c1([N+](=O)[O-])ccc2ccccc2c1
# c1([NH3+])ccc2ccccc2c1
# found match
# c1c(I)cc2ccccc2c1
# c1c(Br)cc2ccccc2c1
# c1c(Cl)cc2ccccc2c1
# c1c(F)cc2ccccc2c1
# c1c(C(Cl)(Cl)(Cl))cc2ccccc2c1
# c1c(C(F)(F)(F))cc2ccccc2c1
# c1c(C(=O)[O-])cc2ccccc2c1
# c1c(C(=O))cc2ccccc2c1
# c1c(C#N)cc2ccccc2c1
# c1c([N+](=O)[O-])cc2ccccc2c1
# c1c([NH3+])cc2ccccc2c1
# found match
# c1ccc2c(I)cccc2c1
# c1ccc2c(Br)cccc2c1
# c1ccc2c(Cl)cccc2c1
# c1ccc2c(F)cccc2c1
# c1ccc2c(C(Cl)(Cl)(Cl))cccc2c1
# c1ccc2c(C(F)(F)(F))cccc2c1
# c1ccc2c(C(=O)[O-])cccc2c1
# c1ccc2c(C(=O))cccc2c1
# c1ccc2c(C#N)cccc2c1
# c1ccc2c([N+](=O)[O-])cccc2c1
# c1ccc2c([NH3+])cccc2c1
# found match
# c1ccc2ccc(I)cc2c1
# c1ccc2ccc(Br)cc2c1
# c1ccc2ccc(Cl)cc2c1
# c1ccc2ccc(F)cc2c1
# c1ccc2ccc(C(Cl)(Cl)(Cl))cc2c1
# c1ccc2ccc(C(F)(F)(F))cc2c1
# c1ccc2ccc(C(=O)[O-])cc2c1
# c1ccc2ccc(C(=O))cc2c1
# c1ccc2ccc(C#N)cc2c1
# c1ccc2ccc([N+](=O)[O-])cc2c1
# c1ccc2ccc([NH3+])cc2c1
# Best score: 0 for c1ccc2ccccc2c1
# found match
# c1(I)ccc2cc3ccccc3cc2c1
# c1(Br)ccc2cc3ccccc3cc2c1
# c1(Cl)ccc2cc3ccccc3cc2c1
# c1(F)ccc2cc3ccccc3cc2c1
# c1(C(Cl)(Cl)(Cl))ccc2cc3ccccc3cc2c1
# c1(C(F)(F)(F))ccc2cc3ccccc3cc2c1
# c1(C(=O)[O-])ccc2cc3ccccc3cc2c1
# c1(C(=O))ccc2cc3ccccc3cc2c1
# c1(C#N)ccc2cc3ccccc3cc2c1
# c1([N+](=O)[O-])ccc2cc3ccccc3cc2c1
# c1([NH3+])ccc2cc3ccccc3cc2c1
# found match
# c1c(I)cc2cc3ccccc3cc2c1
# c1c(Br)cc2cc3ccccc3cc2c1
# c1c(Cl)cc2cc3ccccc3cc2c1
# c1c(F)cc2cc3ccccc3cc2c1
# c1c(C(Cl)(Cl)(Cl))cc2cc3ccccc3cc2c1
# c1c(C(F)(F)(F))cc2cc3ccccc3cc2c1
# c1c(C(=O)[O-])cc2cc3ccccc3cc2c1
# c1c(C(=O))cc2cc3ccccc3cc2c1
# c1c(C#N)cc2cc3ccccc3cc2c1
# c1c([N+](=O)[O-])cc2cc3ccccc3cc2c1
# c1c([NH3+])cc2cc3ccccc3cc2c1
# found match
# c1ccc2c(I)c3ccccc3cc2c1
# c1ccc2c(Br)c3ccccc3cc2c1
# c1ccc2c(Cl)c3ccccc3cc2c1
# c1ccc2c(F)c3ccccc3cc2c1
# c1ccc2c(C(Cl)(Cl)(Cl))c3ccccc3cc2c1
# c1ccc2c(C(F)(F)(F))c3ccccc3cc2c1
# c1ccc2c(C(=O)[O-])c3ccccc3cc2c1
# c1ccc2c(C(=O))c3ccccc3cc2c1
# c1ccc2c(C#N)c3ccccc3cc2c1
# c1ccc2c([N+](=O)[O-])c3ccccc3cc2c1
# c1ccc2c([NH3+])c3ccccc3cc2c1
# found match
# c1ccc2cc3c(I)cccc3cc2c1
# c1ccc2cc3c(Br)cccc3cc2c1
# c1ccc2cc3c(Cl)cccc3cc2c1
# c1ccc2cc3c(F)cccc3cc2c1
# c1ccc2cc3c(C(Cl)(Cl)(Cl))cccc3cc2c1
# c1ccc2cc3c(C(F)(F)(F))cccc3cc2c1
# c1ccc2cc3c(C(=O)[O-])cccc3cc2c1
# c1ccc2cc3c(C(=O))cccc3cc2c1
# c1ccc2cc3c(C#N)cccc3cc2c1
# c1ccc2cc3c([N+](=O)[O-])cccc3cc2c1
# c1ccc2cc3c([NH3+])cccc3cc2c1
# found match
# c1ccc2cc3ccc(I)cc3cc2c1
# c1ccc2cc3ccc(Br)cc3cc2c1
# c1ccc2cc3ccc(Cl)cc3cc2c1
# c1ccc2cc3ccc(F)cc3cc2c1
# c1ccc2cc3ccc(C(Cl)(Cl)(Cl))cc3cc2c1
# c1ccc2cc3ccc(C(F)(F)(F))cc3cc2c1
# c1ccc2cc3ccc(C(=O)[O-])cc3cc2c1
# c1ccc2cc3ccc(C(=O))cc3cc2c1
# c1ccc2cc3ccc(C#N)cc3cc2c1
# c1ccc2cc3ccc([N+](=O)[O-])cc3cc2c1
# c1ccc2cc3ccc([NH3+])cc3cc2c1
# found match
# c1ccc2cc3ccccc3c(I)c2c1
# c1ccc2cc3ccccc3c(Br)c2c1
# c1ccc2cc3ccccc3c(Cl)c2c1
# c1ccc2cc3ccccc3c(F)c2c1
# c1ccc2cc3ccccc3c(C(Cl)(Cl)(Cl))c2c1
# c1ccc2cc3ccccc3c(C(F)(F)(F))c2c1
# c1ccc2cc3ccccc3c(C(=O)[O-])c2c1
# c1ccc2cc3ccccc3c(C(=O))c2c1
# c1ccc2cc3ccccc3c(C#N)c2c1
# c1ccc2cc3ccccc3c([N+](=O)[O-])c2c1
# c1ccc2cc3ccccc3c([NH3+])c2c1
# Best score: 0 for c1ccc2cc3ccccc3cc2c1
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(I)H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(I)H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(I)H]cc1' for input: 'n1c[n(I)H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(Br)H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(Br)H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(Br)H]cc1' for input: 'n1c[n(Br)H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(Cl)H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(Cl)H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(Cl)H]cc1' for input: 'n1c[n(Cl)H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(F)H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(F)H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(F)H]cc1' for input: 'n1c[n(F)H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(C(Cl)(Cl)(Cl))H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(C(Cl)(Cl)(Cl))H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(C(Cl)(Cl)(Cl))H]cc1' for input: 'n1c[n(C(Cl)(Cl)(Cl))H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(C(F)(F)(F))H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(C(F)(F)(F))H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(C(F)(F)(F))H]cc1' for input: 'n1c[n(C(F)(F)(F))H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(C(=O)[O-])H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(C(=O)[O-])H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(C(=O)[O-])H]cc1' for input: 'n1c[n(C(=O)[O-])H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(C(=O))H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(C(=O))H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(C(=O))H]cc1' for input: 'n1c[n(C(=O))H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n(C#N)H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n(C#N)H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n(C#N)H]cc1' for input: 'n1c[n(C#N)H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n([N+](=O)[O-])H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n([N+](=O)[O-])H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n([N+](=O)[O-])H]cc1' for input: 'n1c[n([N+](=O)[O-])H]cc1'
# [16:37:00] SMILES Parse Error: syntax error while parsing: n1c[n([NH3+])H]cc1
# [16:37:00] SMILES Parse Error: check for mistakes around position 6:
# [16:37:00] n1c[n([NH3+])H]cc1
# [16:37:00] ~~~~~^
# [16:37:00] SMILES Parse Error: Failed parsing SMILES 'n1c[n([NH3+])H]cc1' for input: 'n1c[n([NH3+])H]cc1'
